# %%
import sys
import os
import numpy as np
import pandas as pd
import string
import pickle
from tqdm.autonotebook import tqdm
from typing import *


import multiprocessing as mp
from functools import partial
# Out:
# /tmp/ipykernel_46/2438604477.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
df_patients = pd.read_stata('../.data/ADRIAN_2018/patients_active_revised.dta') 
df_script_item = pd.read_stata('../.data/ADRIAN_2018/script_item_active_WITHOUT_gold_standard_revised.dta') 
df_reason_prescription = pd.read_stata('../.data/ADRIAN_2018/reason_prescription_active_WITHOUT_gold_standard_revised.dta') 
df_pathology = pd.read_stata('../.data/ADRIAN_2018/pathology_active_revised.dta') 
df_immunisations = pd.read_stata('../.data/ADRIAN_2018/immunisations_active_revised.dta') 
df_diagnosis_encounter = pd.read_stata('../.data/ADRIAN_2018/diagnosis_encounter_active_WITHOUT_gold_standard_revised.dta') 
df_observations = pd.read_stata('../.data/ADRIAN_2018/observations_active_WITHOUT_gold_standard_revised.dta') 

# check we have all necessary columns + add any dates columns if possible
dates = set(['visit_date', 'result_date', 'given_date', 'observation_date', 'hpt', 'hpt_date'])
df_patients_columns = set(['patientid', 'aborig', 'gender2', 'smoke', 'irsad', 'ieo', 'ieo_q', 'irsad_q']) | (set(df_patients.columns) & dates)
df_script_item_columns = set(['patientid', 'dose', 'frequency', 'med_active_ingr', 'med_name', 'quantity', 'repeats', 'strength']) | (set(df_script_item.columns) & dates)
df_reason_prescription_columns = set(['patientid', 'first_name_presc', 'first_ingred_presc', 'reason']) | (set(df_reason_prescription.columns) & dates)
df_pathology_columns = set(['patientid', 'result_name', 'result_value']) | (set(df_pathology.columns) & dates)
df_immunisations_columns = set(['patientid', 'vaccine_name']) | (set(df_immunisations.columns) & dates)
df_observations_columns = set(['patientid', 'observation_name', 'observation_value']) | (set(df_observations.columns) & dates)
df_diagnosis_encounter_columns = set(['patientid', 'reason']) | (set(df_diagnosis_encounter.columns) & dates)

all(
    [
    (lambda cols: (set(df_patients.columns) and cols) == set(cols))(df_patients_columns),
    (lambda cols: (set(df_script_item.columns) and cols) == set(cols))(df_script_item_columns),
    (lambda cols: (set(df_reason_prescription.columns) and cols) == set(cols))(df_reason_prescription_columns),
    (lambda cols: (set(df_pathology.columns) and cols) == set(cols))(df_pathology_columns),
    (lambda cols: (set(df_immunisations.columns) and cols) == set(cols))(df_immunisations_columns),
    (lambda cols: (set(df_observations.columns) and cols) == set(cols))(df_observations_columns),
    (lambda cols: (set(df_diagnosis_encounter.columns) and cols) == set(cols))(df_diagnosis_encounter_columns),
    ]
)

# Only have columns I want
df_patients = df_patients.drop(columns=set(df_patients.columns) - df_patients_columns)
df_script_item = df_script_item.drop(columns=set(df_script_item.columns) - df_script_item_columns)
df_reason_prescription = df_reason_prescription.drop(columns=set(df_reason_prescription.columns) - df_reason_prescription_columns)
df_pathology = df_pathology.drop(columns=set(df_pathology.columns) - df_pathology_columns)
df_immunisations = df_immunisations.drop(columns=set(df_immunisations.columns) - df_immunisations_columns)
df_observations = df_observations.drop(columns=set(df_observations.columns) - df_observations_columns)
df_diagnosis_encounter = df_diagnosis_encounter.drop(columns=set(df_diagnosis_encounter.columns) - df_diagnosis_encounter_columns)

# %%
# (cleanup)Rename different dates to all be the same col name 
df_script_item = df_script_item.rename(columns={'visit_date': 'field_date'})
df_reason_prescription = df_reason_prescription.rename(columns={'visit_date': 'field_date'})
df_pathology = df_pathology.rename(columns={'result_date': 'field_date'})
df_immunisations = df_immunisations.rename(columns={'given_date': 'field_date'})
df_observations = df_observations.rename(columns={'observation_date': 'field_date'})
df_diagnosis_encounter = df_diagnosis_encounter.rename(columns={'visit_date': 'field_date'})

# %%
# check we have all necessary columns + add any dates columns if possible
dates = set(['field_date', 'hpt', 'hpt_date'])
df_patients_columns = set(['patientid', 'aborig', 'gender2', 'smoke', 'irsad', 'ieo', 'ieo_q', 'irsad_q']) | (set(df_patients.columns) & dates)
df_script_item_columns = set(['patientid', 'dose', 'frequency', 'med_active_ingr', 'med_name', 'quantity', 'repeats', 'strength']) | (set(df_script_item.columns) & dates)
df_reason_prescription_columns = set(['patientid', 'first_name_presc', 'first_ingred_presc', 'reason']) | (set(df_reason_prescription.columns) & dates)
df_pathology_columns = set(['patientid', 'result_name', 'result_value']) | (set(df_pathology.columns) & dates)
df_immunisations_columns = set(['patientid', 'vaccine_name']) | (set(df_immunisations.columns) & dates)
df_observations_columns = set(['patientid', 'observation_name', 'observation_value']) | (set(df_observations.columns) & dates)
df_diagnosis_encounter_columns = set(['patientid', 'reason']) | (set(df_diagnosis_encounter.columns) & dates)

all(
    [
    (lambda cols: (set(df_patients.columns) and cols) == set(cols))(df_patients_columns),
    (lambda cols: (set(df_script_item.columns) and cols) == set(cols))(df_script_item_columns),
    (lambda cols: (set(df_reason_prescription.columns) and cols) == set(cols))(df_reason_prescription_columns),
    (lambda cols: (set(df_pathology.columns) and cols) == set(cols))(df_pathology_columns),
    (lambda cols: (set(df_immunisations.columns) and cols) == set(cols))(df_immunisations_columns),
    (lambda cols: (set(df_observations.columns) and cols) == set(cols))(df_observations_columns),
    (lambda cols: (set(df_diagnosis_encounter.columns) and cols) == set(cols))(df_diagnosis_encounter_columns),
    ]
)
# Out:
# True

# %%
def patient__get_patient_entry(patient_id: str) -> List[dict]:
    # get dataframe and only this patientid
    df = df_patients[
        (df_patients["patientid"] == patient_id)
    ].copy()

    # for every sample in dataset
    dataset_entries = []
    for idx, dataset_row in df.iterrows():
        dataset_entries.append(dataset_row.to_json())

    return dataset_entries

def script_item_active__get_patient_entry(patient_id: str) -> List[dict]:
    # get dataframe and only this patientid
    df = df_script_item[
        (df_script_item["patientid"] == patient_id)
    ].copy()
    
    # for every sample in dataset
    dataset_entries = []
    for idx, dataset_row in df.iterrows():
        dataset_entries.append(dataset_row.to_json())

    return dataset_entries


def reason_prescription_active__get_patient_entry(patient_id: str) -> List[dict]:
    # get dataframe and only this patientid
    df = df_reason_prescription[
        (df_reason_prescription["patientid"] == patient_id)
    ].copy()

    # for every sample in dataset
    dataset_entries = []
    for idx, dataset_row in df.iterrows():
        dataset_entries.append(dataset_row.to_json())

    return dataset_entries


def pathology_result2015_2017_active__get_patient_entry(patient_id: str) -> List[dict]:
    # get dataframe and only this patientid
    df = df_pathology[
        (
            df_pathology["patientid"]
            == patient_id
        )
    ].copy()

    # for every sample in dataset
    dataset_entries = []
    for idx, dataset_row in df.iterrows():
        dataset_entries.append(dataset_row.to_json())

    return dataset_entries


def immunisation_active__get_patient_entry(patient_id: str) -> List[dict]:
    # get dataframe and only this patientid
    df = df_immunisations[
        (
            df_immunisations["patientid"]
            == patient_id
        )
    ].copy()

    # for every sample in dataset
    dataset_entries = []
    for idx, dataset_row in df.iterrows():
        dataset_entries.append(dataset_row.to_json())

    return dataset_entries


def observation_active__get_patient_entry(patient_id: str) -> List[dict]:
    # get dataframe and only this patientid
    df = df_observations[
        (
            df_observations["patientid"]
            == patient_id
        )
    ].copy()

    # for every sample in dataset
    dataset_entries = []
    for idx, dataset_row in df.iterrows():
        dataset_entries.append(dataset_row.to_json())

    return dataset_entries


def encounter_reason_active__get_patient_entry(patient_id: str) -> List[dict]:
    # get dataframe and only this patientid
    df = df_diagnosis_encounter[
        (
            df_diagnosis_encounter["patientid"]
            == patient_id
        )
    ].copy()

    # for every sample in dataset
    dataset_entries = []
    for idx, dataset_row in df.iterrows():
        dataset_entries.append(dataset_row.to_json())

    return dataset_entries

diag_conversion = {
    'Yes': 1,
    'No': 0,
    'Maybe': -1
}

def generate_patient_data(active_patient_row: pd.core.series.Series) -> dict:
    """
    Given a pandas dataframe, generate json reports over various datasets
    """
    patient_sample = {
        "id": active_patient_row.patientid,
        "data": {},
        "label": diag_conversion[active_patient_row.hpt],
    }

    patient_sample["data"]["patient"] = patient__get_patient_entry(
        active_patient_row.patientid
    )

    patient_sample["data"]["scripts"] = script_item_active__get_patient_entry(
        active_patient_row.patientid
    )

    patient_sample["data"]["prescriptions"] = reason_prescription_active__get_patient_entry(
        active_patient_row.patientid
    )

    patient_sample["data"]["pathology"] = pathology_result2015_2017_active__get_patient_entry(
        active_patient_row.patientid
    )

    patient_sample["data"]["immunisations"] = immunisation_active__get_patient_entry(
        active_patient_row.patientid
    )

    patient_sample["data"]["observations"] = observation_active__get_patient_entry(
        active_patient_row.patientid
    )

    patient_sample["data"]["encounter_reasons"] = encounter_reason_active__get_patient_entry(
        active_patient_row.patientid
    )
        
    return patient_sample

# %%
import json
import pathlib
medical_corpus_pathlib = pathlib.Path('../.data/processed_medical_corpus.json')

# %%
if medical_corpus_pathlib.is_file():
    with open(medical_corpus_pathlib, 'r') as f:
        results = json.load(f)
        print(len(results))
else:
    results = []
    print('not file')
# Out:
# 735333

# %%
multiprocess = True

def f(job) -> dict:
    index, row = job
    return generate_patient_data(row)

if __name__ == "__main__":
    job_generator = list(df_patients[['patientid', 'hpt']][len(results):].iterrows())

    if multiprocess:
        with mp.Pool(12) as pool:
            for result in tqdm(pool.imap_unordered(f, job_generator, chunksize=8), total=len(job_generator)):
                results.extend([result])
    else:
        for row_idx, patient in tqdm(job_generator, total=len(job_generator)):
            result = generate_patient_data(patient)
            results.extend([result])
    
    with open(medical_corpus_pathlib, 'w') as f:
        json.dump(results, f)
# Out:
#   0%|          | 0/685333 [00:00<?, ?it/s]

# %% [markdown]
# # Building train/val & schema

# %%
import json

with open(medical_corpus_pathlib, 'r') as f:
    medical_dataset = json.load(f)
    print(len(medical_dataset))
# Out:
# 735333

# %% [markdown]
# ## Raw Data sanitisation
# For each sample, get the data, for every dataset parse into json, for every field in dataset group by same date (useful for shuffling data), compile a list starting from earliest record ending in either latest or when we reach their hypertension diagnosise date.
#
# For every field, remove set(['field_date', 'hpt', 'hpt_date', 'patientid']), and check if there is anything else to clean.

# %%
from loguru import logger
from itertools import groupby
from operator import itemgetter
from typing import Dict, Any, List, Set
from collections import OrderedDict
import dataclasses
from src.datasets.medical_data import PatientData

Json = Dict[str, Any]

class RemoveKeysAndCastToString:
    def __init__(self, disallowed_keys: Set[str]):
        self.disallowed_keys = disallowed_keys

    def __call__(self, dic: dict) -> OrderedDict:
        return OrderedDict((
            (k,str(v)) 
            for k,v in dic.items() 
            if k not in self.disallowed_keys
        ))
    
def make_time_grouped_data(data: List[str]) -> List[List[Json]]:
    """
    So that data in the same day can be randomly shuffled.
    Return a list of ordered dicts, also sanitise.
    """

    parsed_data = [json.loads(x) for x in data]

    if not parsed_data:
        # logger.warning('No data parsed')
        return None
    
    if 'field_date' in parsed_data[0]:
        parsed_data.sort(key=itemgetter('field_date'))
        time_ordered_and_grouped = OrderedDict(
            (date, list(group_generator)) 
            for (date, group_generator) in groupby(parsed_data,key=itemgetter('field_date'))   
        )
    else:
        time_ordered_and_grouped = {0: parsed_data}

    # sanitise: remove data after diagnosis date 
    if parsed_data[0].get('hpt') == 'Yes':
        time_ordered_and_grouped = OrderedDict(
            (time, group)
            for time, group in time_ordered_and_grouped.items()
            if time < parsed_data[0].get('hpt_date')
        )

    if not time_ordered_and_grouped:
        # logger.warning('No data before hypertensive diagnosis')
        return None
    
    # sanitise: remove keys we don't want the model to see
    key_remover = RemoveKeysAndCastToString({'patientid', 'field_date', 'hpt', 'hpt_date'})
    time_ordered_and_grouped = OrderedDict(
        (time, [key_remover(field) for field in group])
        for time, group in time_ordered_and_grouped.items()
    )

    return time_ordered_and_grouped


def dfs_unpack_json(
    parent: Any, branch: str = "", separator: str = "."
) -> Generator[Tuple[str, str], None, None]:
    if isinstance(parent, dict):
        for key, value in parent.items():
            if isinstance(key, int):
                # we can ignore the date grouping as a key
                yield from dfs_unpack_json(
                    parent=value,
                    branch=branch,
                    separator=separator,
                )
            else:
                yield from dfs_unpack_json(
                    parent=value,
                    branch=branch + (separator if branch else "") + key,
                    separator=separator,
                )
    elif type(parent) in [list, tuple]:
        for value in parent:
            yield from dfs_unpack_json(parent=value, branch=branch, separator=separator)
    else:
        yield branch, str(parent)
        
def unpack_flattened_keys(sample):
    return set(key for key, value in dfs_unpack_json(sample))



sanitised_medical_data = []
all_medical_data_keys = set()
for sample in tqdm(medical_dataset, total=len(medical_dataset)):
    patient_id = sample.get('id')
    patient_label = sample.get('label')
    
    data = OrderedDict((k, make_time_grouped_data(v)) for k,v in sample.get('data').items())
    
    no_datas = [type(patient_data) == type(None) for k, patient_data in data.items()]
    if all(no_datas):
        assert False, 'No data parsed'
    
    all_medical_data_keys = all_medical_data_keys | unpack_flattened_keys(data)
    
    ordered_patient_data = OrderedDict()
    ordered_patient_data['id'] = patient_id
    ordered_patient_data['label'] = patient_label
    ordered_patient_data['data'] = data
    
    sanitised_medical_data.append(PatientData(
        uid = patient_id,
        label = patient_label,
        data = data
    ))
# Out:
#   0%|          | 0/735333 [00:00<?, ?it/s]

# %%
import random
positives = [patient_data for patient_data in sanitised_medical_data if patient_data.human_readable_label == "Yes"]

negatives = [patient_data for patient_data in sanitised_medical_data if patient_data.human_readable_label == "No"]

maybies = [patient_data for patient_data in sanitised_medical_data if patient_data.human_readable_label == "Maybe"]
random.shuffle(positives)
random.shuffle(negatives)
random.shuffle(maybies)
len(positives), len(negatives), len(maybies)
# Out:
# (59016, 626682, 49635)

# %%
import itertools
from pathlib import Path
TRAIN_DATASET_FILEPATH = '../.data/medical_data_train_with_metadata'
VAL_DATASET_FILEPATH = '../.data/medical_data_val_with_metadata'

num_positives = int(len(positives)*0.8)
num_negatives = int(len(negatives)*0.8)
train_dataset = list(itertools.chain(positives[:num_positives], negatives[:num_negatives]))
val_dataset = list(itertools.chain(positives[num_positives:], negatives[num_negatives:]))

# %% [markdown]
# ## Schema
# We want each field to come with a token that represnts dataset start and end, field, field_runes_padded

# %%
schema = {
    'schema': sorted(list(all_medical_data_keys))
}

with open('schema.json', 'w') as outfile:
    json.dump(schema, outfile)

# %% [markdown]
# ## Saving samples

# %%
import torch
def write_data_to_disk(data: PatientData, file_path: pathlib.Path) -> bool:
    file_path.parent.mkdir(parents=True, exist_ok=True)
    
    torch.save(data, file_path)

    return True

# %%
import random
import itertools
from pathlib import Path
TRAIN_DATASET_FILEPATH = '../.data/medical_data_train_with_metadata'
VAL_DATASET_FILEPATH = '../.data/medical_data_val_with_metadata'

train_dataset = list(itertools.chain(positives[:num_positives], negatives[:num_negatives]))
val_dataset = list(itertools.chain(positives[num_positives:], negatives[num_negatives:]))

for sample in tqdm(train_dataset, total=len(train_dataset)):
    filename = (
        Path(TRAIN_DATASET_FILEPATH)
        / f"class{sample.label}"
        / f"sample_patientid_{sample.uid}.pt"
    )

    write_data_to_disk(
        data=sample, file_path=filename
    )

for sample in tqdm(val_dataset, total=len(val_dataset)):
    filename = (
        Path(VAL_DATASET_FILEPATH)
        / f"class{sample.label}"
        / f"sample_patientid_{sample.uid}.pt"
    )

    write_data_to_disk(
        data=sample, file_path=filename
    )
# Out:
#   0%|          | 0/548557 [00:00<?, ?it/s]
#   0%|          | 0/137141 [00:00<?, ?it/s]

# %%
import glob
import pathlib

len(list(pathlib.Path('../.data/medical_data_train_with_metadata/class0/').glob('*.pt')))
# Out:
# 34108

# %%
len(list(pathlib.Path('../.data/medical_data_train_with_metadata/class1/').glob('*.pt')))
# Out:
# 3170

# %%
len(list(pathlib.Path('../.data/medical_data_val_with_metadata/class0/').glob('*.pt')))
# Out:
# 8528

# %%
len(list(pathlib.Path('../.data/medical_data_val_with_metadata/class1/').glob('*.pt')))
# Out:
# 793

# %%
import torch
import glob
import dataclasses
from src.datasets.medical_data import PatientData

for patient_id in [1611489, 1509283, 2569768, 2608285, 2650036, 1638824, 2783447, 1998712,
        3016693,  715960, 2445458, 2864352, 2088872,  516763, 1455156, 1497152,
        1362617, 2729893, 2546927, 2162700, 1028866, 1862622,  696967, 2509926,
        3162513,  856450,  774542, 1270402, 2593633, 1995239, 1564290,  568979]:

    print(glob.glob(f'../.data/medical_data_train_with_metadata/*/sample_patientid_{str(patient_id)}.pt'))
    for file in glob.glob(f'../.data/medical_data_train_with_metadata/*/sample_patientid_{str(patient_id)}.pt'):
#         print(file)
        sample = torch.load(file)
        print(sample)
#         for patient_dataset in sample.data:
#             print(len(patient_dataset))
    
# sample
# Out:
# ['../.data/medical_data_train_with_metadata/class1/sample_patientid_1611489.pt']
# PatientData(uid=1611489, label=1, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Not stated'), ('gender2', 'Male'), ('smoke', 'Non smoker'), ('irsad', '9'), ('ieo', '8.0'), ('ieo_q', '2nd upper quintile'), ('irsad_q', 'Upper quintile')])])])), ('scripts', OrderedDict([(1461283200000, [OrderedDict([('dose', '1'), ('frequency', '5'), ('med_active_ingr', 'TEMAZEPAM'), ('med_name', 'NORMISON'), ('quantity', '25'), ('repeats', '0'), ('strength', '10mg')]), OrderedDict([('dose', '½'), ('frequency', '2'), ('med_active_ingr', 'ESCITALOPRAM OXALATE'), ('med_name', 'LEXAPRO'), ('quantity', '28'), ('repeats', '0'), ('strength', '10mg')])])])), ('prescriptions', OrderedDict([(1461283200000, [OrderedDict([('first_name_presc', 'NORMISON'), ('first_ingred_presc', 'TEMAZEPAM'), ('reason', '')])])])), ('pathology', None), ('immunisations', None), ('observations', OrderedDict([(1461283200000, [OrderedDict([('observation_name', 'PULSE'), ('observation_value', '70')])])])), ('encounter_reasons', OrderedDict([(1443657600000, [OrderedDict([('reason', 'THR')])])]))]))
# ['../.data/medical_data_train_with_metadata/class0/sample_patientid_1509283.pt']
# PatientData(uid=1509283, label=0, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Female'), ('smoke', 'Non smoker'), ('irsad', '9'), ('ieo', '9.0'), ('ieo_q', 'Upper quintile'), ('irsad_q', 'Upper quintile')])])])), ('scripts', None), ('prescriptions', None), ('pathology', None), ('immunisations', None), ('observations', OrderedDict([(1464825600000, [OrderedDict([('observation_name', 'PULSE'), ('observation_value', '89')])]), (1464912000000, [OrderedDict([('observation_name', 'LDL'), ('observation_value', '1.7')]), OrderedDict([('observation_name', 'CHOL'), ('observation_value', '3.0')]), OrderedDict([('observation_name', 'CREATININE'), ('observation_value', '62')]), OrderedDict([('observation_name', 'TRIG'), ('observation_value', '0.7')]), OrderedDict([('observation_name', 'HDL'), ('observation_value', '1.0')]), OrderedDict([('observation_name', 'BSL'), ('observation_value', '5.8')])]), (1469145600000, [OrderedDict([('observation_name', 'CREATININE'), ('observation_value', '66')])])])), ('encounter_reasons', OrderedDict([(1426809600000, [OrderedDict([('reason', 'WOUND CARE')])]), (1451606400000, [OrderedDict([('reason', "HODGKIN'S DISEASE")])]), (1465171200000, [OrderedDict([('reason', 'REGISTERED NURSE')])]), (1466726400000, [OrderedDict([('reason', '? ? INFLAMMATORY BOWEL DISEASE')]), OrderedDict([('reason', 'NURSE')])]), (1501632000000, [OrderedDict([('reason', 'OSTEOPOROSIS - PREVENTIVE CARE')])])]))]))
# ['../.data/medical_data_train_with_metadata/class0/sample_patientid_2569768.pt']
# PatientData(uid=2569768, label=0, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Female'), ('smoke', 'Smoker'), ('irsad', '7'), ('ieo', '7.0'), ('ieo_q', '2nd upper quintile'), ('irsad_q', '2nd upper quintile')])])])), ('scripts', OrderedDict([(1424304000000, [OrderedDict([('dose', 'Apply top'), ('frequency', '7'), ('med_active_ingr', 'TRIAMCINOLONE ACETONIDE, NEOMYCIN SULFATE, GRAMICIDIN, NYSTATIN'), ('med_name', 'KENACOMB'), ('quantity', '1'), ('repeats', '1'), ('strength', '')])]), (1425340800000, [OrderedDict([('dose', '1'), ('frequency', '7'), ('med_active_ingr', 'AMOXICILLIN'), ('med_name', 'AMOXIL'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg')])]), (1426118400000, [OrderedDict([('dose', '1'), ('frequency', '6'), ('med_active_ingr', 'AMOXYCILLIN, POTASSIUM CLAVULANATE'), ('med_name', 'AUGMENTIN'), ('quantity', '10'), ('repeats', '1'), ('strength', '875mg;125mg')])]), (1427155200000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'VENLAFAXINE HYDROCHLORIDE'), ('med_name', 'EFEXOR'), ('quantity', '28'), ('repeats', '0'), ('strength', '75mg')])]), (1434672000000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'VENLAFAXINE HYDROCHLORIDE'), ('med_name', 'VENLAFAXINE'), ('quantity', '28'), ('repeats', '5'), ('strength', '150mg')])]), (1436572800000, [OrderedDict([('dose', '1-2 pufs'), ('frequency', '6'), ('med_active_ingr', 'FLUTICASONE PROPIONATE, SALMETEROL XINAFOATE'), ('med_name', 'SERETIDE'), ('quantity', '1'), ('repeats', '5'), ('strength', '250mcg;25mcg/dose')])]), (1441324800000, [OrderedDict([('dose', 'top'), ('frequency', '0'), ('med_active_ingr', 'MUPIROCIN'), ('med_name', 'BACTROBAN'), ('quantity', '1'), ('repeats', '0'), ('strength', '2%')])]), (1447372800000, [OrderedDict([('dose', 'top'), ('frequency', '1'), ('med_active_ingr', 'BRIMONIDINE'), ('med_name', 'MIRVASO'), ('quantity', '1'), ('repeats', '0'), ('strength', '3.3mg')]), OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'VENLAFAXINE HYDROCHLORIDE'), ('med_name', 'VENLAFAXINE'), ('quantity', '28'), ('repeats', '5'), ('strength', '150mg')])]), (1453939200000, [OrderedDict([('dose', '2'), ('frequency', '6'), ('med_active_ingr', 'CEPHALEXIN'), ('med_name', 'KEFLEX'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg')]), OrderedDict([('dose', ''), ('frequency', '0'), ('med_active_ingr', 'HYDROCORTISONE'), ('med_name', 'HYDROCORTISONE'), ('quantity', '1'), ('repeats', '0'), ('strength', '1%')])]), (1456185600000, [OrderedDict([('dose', 'top'), ('frequency', '6'), ('med_active_ingr', 'METRONIDAZOLE'), ('med_name', 'ROZEX'), ('quantity', '1'), ('repeats', '2'), ('strength', '0.75%')]), OrderedDict([('dose', '1'), ('frequency', '6'), ('med_active_ingr', 'AMOXYCILLIN, POTASSIUM CLAVULANATE'), ('med_name', 'AUGMENTIN'), ('quantity', '10'), ('repeats', '1'), ('strength', '875mg;125mg')]), OrderedDict([('dose', '1-2 pufs'), ('frequency', '6'), ('med_active_ingr', 'FLUTICASONE PROPIONATE, SALMETEROL XINAFOATE'), ('med_name', 'SERETIDE'), ('quantity', '1'), ('repeats', '5'), ('strength', '250mcg;25mcg/dose')])]), (1458172800000, [OrderedDict([('dose', '1'), ('frequency', '0'), ('med_active_ingr', 'HYDROXOCOBALAMIN'), ('med_name', 'NEO-B12'), ('quantity', '3'), ('repeats', '0'), ('strength', '1mg/mL')])]), (1461110400000, [OrderedDict([('dose', ''), ('frequency', '0'), ('med_active_ingr', 'INACTIVATED QUADRIVALENT INFLUENZA VACCINE'), ('med_name', 'FLUQUADRI'), ('quantity', '1'), ('repeats', '0'), ('strength', '')]), OrderedDict([('dose', '2 puffs'), ('frequency', '9'), ('med_active_ingr', 'SALBUTAMOL SULFATE'), ('med_name', 'VENTOLIN'), ('quantity', '2'), ('repeats', '5'), ('strength', '100mcg/dose')]), OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'VENLAFAXINE HYDROCHLORIDE'), ('med_name', 'VENLAFAXINE'), ('quantity', '28'), ('repeats', '5'), ('strength', '150mg')])]), (1468 ...
# ['../.data/medical_data_train_with_metadata/class0/sample_patientid_2608285.pt']
# PatientData(uid=2608285, label=0, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Male'), ('smoke', 'Non smoker'), ('irsad', '6'), ('ieo', '5.0'), ('ieo_q', 'intermediate quintile'), ('irsad_q', 'intermediate quintile')])])])), ('scripts', OrderedDict([(1420761600000, [OrderedDict([('dose', '1-2'), ('frequency', 'b.d.'), ('med_active_ingr', 'FLUTICASONE/SALMETEROL'), ('med_name', 'SERETIDE MDI'), ('quantity', '1*120 dose'), ('repeats', '5'), ('strength', '250mcg-25mcg/dose')])]), (1430179200000, [OrderedDict([('dose', '2'), ('frequency', 't.i.d.'), ('med_active_ingr', 'AMOXICILLIN'), ('med_name', 'AMOXICILLIN'), ('quantity', '20'), ('repeats', '1'), ('strength', '500mg')]), OrderedDict([('dose', '2'), ('frequency', 'daily'), ('med_active_ingr', 'PREDNISOLONE'), ('med_name', 'PREDNISOLONE'), ('quantity', '30'), ('repeats', '0'), ('strength', '25mg')])]), (1430870400000, [OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'OMEPRAZOLE'), ('med_name', 'OMEPRAZOLE'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')])]), (1438905600000, [OrderedDict([('dose', '1'), ('frequency', 'b.d.'), ('med_active_ingr', 'AMOXICILLIN/CLAVULANATE'), ('med_name', 'AUGMENTIN DUO FORTE'), ('quantity', '10'), ('repeats', '0'), ('strength', '875mg/125mg')]), OrderedDict([('dose', '2'), ('frequency', 'daily'), ('med_active_ingr', 'PREDNISOLONE'), ('med_name', 'PREDNISOLONE'), ('quantity', '30'), ('repeats', '0'), ('strength', '25mg')])]), (1458086400000, [OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'OMEPRAZOLE'), ('med_name', 'OMEPRAZOLE'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')]), OrderedDict([('dose', '2'), ('frequency', 'daily'), ('med_active_ingr', 'PREDNISOLONE'), ('med_name', 'PREDNISOLONE'), ('quantity', '30'), ('repeats', '4'), ('strength', '25mg')]), OrderedDict([('dose', '2-4'), ('frequency', 'q.4.h.'), ('med_active_ingr', 'SALBUTAMOL'), ('med_name', 'SALBUTAMOL'), ('quantity', '2*200 dose'), ('repeats', '5'), ('strength', '100mcg/dose')]), OrderedDict([('dose', '1-2'), ('frequency', 'b.d.'), ('med_active_ingr', 'FLUTICASONE/SALMETEROL'), ('med_name', 'FLUTICASONE PROPIONATE/SALMETEROL'), ('quantity', '120 dose'), ('repeats', '5'), ('strength', '250mcg-25mcg/dose')])]), (1470268800000, [OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'PREDNISOLONE'), ('med_name', 'PREDNISOLONE'), ('quantity', '30'), ('repeats', '4'), ('strength', '25mg')])]), (1493769600000, [OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'OMEPRAZOLE'), ('med_name', 'OMEPRAZOLE'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')]), OrderedDict([('dose', '2'), ('frequency', 'b.d.'), ('med_active_ingr', 'FLUTICASONE/SALMETEROL'), ('med_name', 'FLUTICASONE PROPIONATE/SALMETEROL'), ('quantity', '120 dose'), ('repeats', '5'), ('strength', '250mcg-25mcg/dose')])]), (1513209600000, [OrderedDict([('dose', '1 puff'), ('frequency', 'b.d.'), ('med_active_ingr', 'ACLIDINIUM'), ('med_name', 'BRETARIS GENUAIR'), ('quantity', '60 dose'), ('repeats', '5'), ('strength', '343mcg/actuation (322mcg delivered to patient)')]), OrderedDict([('dose', '2'), ('frequency', 'b.d.'), ('med_active_ingr', 'FLUTICASONE/SALMETEROL'), ('med_name', 'FLUTICASONE PROPIONATE/SALMETEROL'), ('quantity', '120 dose'), ('repeats', '5'), ('strength', '250mcg-25mcg/dose')]), OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'OMEPRAZOLE'), ('med_name', 'OMEPRAZOLE'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')])]), (1522886400000, [OrderedDict([('dose', '2'), ('frequency', 'b.d.'), ('med_active_ingr', 'FLUTICASONE/SALMETEROL'), ('med_name', 'FLUTICASONE PROPIONATE/SALMETEROL'), ('quantity', '120 dose'), ('repeats', '5'), ('strength', '250mcg-25mcg/dose')]), OrderedDict([('dose', '2-4'), ('frequency', 'q.4.h.'), ('med_active_ingr', 'SALBUTAMOL'), ('med_name', 'SALBU ...
# ['../.data/medical_data_train_with_metadata/class0/sample_patientid_2650036.pt']
# PatientData(uid=2650036, label=0, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Male'), ('smoke', 'Non smoker'), ('irsad', '4'), ('ieo', '3.0'), ('ieo_q', '2nd lower quintile'), ('irsad_q', '2nd lower quintile')])])])), ('scripts', OrderedDict([(1442448000000, [OrderedDict([('dose', '1'), ('frequency', '0'), ('med_active_ingr', 'AZITHROMYCIN'), ('med_name', 'AZITHROMYCIN'), ('quantity', '3'), ('repeats', '0'), ('strength', '500mg')])]), (1466553600000, [OrderedDict([('dose', '1'), ('frequency', '6'), ('med_active_ingr', 'PHENOXYMETHYLPENICILLIN'), ('med_name', 'PHENOXYMETHYLPENICILLIN'), ('quantity', '50'), ('repeats', '0'), ('strength', '500mg')])]), (1468281600000, [OrderedDict([('dose', ''), ('frequency', '0'), ('med_active_ingr', 'CHLORAMPHENICOL'), ('med_name', 'CHLORSIG'), ('quantity', '1'), ('repeats', '0'), ('strength', '0.5%')])]), (1493769600000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'AZITHROMYCIN'), ('med_name', 'AZITHROMYCIN'), ('quantity', '2'), ('repeats', '0'), ('strength', '500mg')])]), (1493856000000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'AZITHROMYCIN'), ('med_name', 'AZITHROMYCIN'), ('quantity', '2'), ('repeats', '1'), ('strength', '500mg')])])])), ('prescriptions', OrderedDict([(1442448000000, [OrderedDict([('first_name_presc', 'AZITHROMYCIN'), ('first_ingred_presc', 'AZITHROMYCIN'), ('reason', 'PERTUSSIS PROPHYLAXIS')])]), (1466553600000, [OrderedDict([('first_name_presc', 'PHENOXYMETHYLPENICILLIN'), ('first_ingred_presc', 'PHENOXYMETHYLPENICILLIN'), ('reason', 'PHARYNGITIS')])]), (1468281600000, [OrderedDict([('first_name_presc', 'CHLORSIG'), ('first_ingred_presc', 'CHLORAMPHENICOL'), ('reason', 'CONJUNCTIVITIS')])]), (1493769600000, [OrderedDict([('first_name_presc', 'AZITHROMYCIN'), ('first_ingred_presc', 'AZITHROMYCIN'), ('reason', 'PERTUSSIS PROPHYLAXIS')])]), (1493856000000, [OrderedDict([('first_name_presc', 'AZITHROMYCIN'), ('first_ingred_presc', 'AZITHROMYCIN'), ('reason', 'PERTUSSIS PROPHYLAXIS')])])])), ('pathology', None), ('immunisations', None), ('observations', OrderedDict([(1433376000000, [OrderedDict([('observation_name', 'WAIST'), ('observation_value', '105')]), OrderedDict([('observation_name', 'HEIGHT'), ('observation_value', '179')]), OrderedDict([('observation_name', 'BMI'), ('observation_value', '29.6')]), OrderedDict([('observation_name', 'WEIGHT'), ('observation_value', '95')]), OrderedDict([('observation_name', 'PULSE'), ('observation_value', '80')])]), (1442448000000, [OrderedDict([('observation_name', 'TEMP'), ('observation_value', '36.7')]), OrderedDict([('observation_name', 'RESP'), ('observation_value', '20')])]), (1454198400000, [OrderedDict([('observation_name', 'TEMP'), ('observation_value', '37.4')])]), (1491350400000, [OrderedDict([('observation_name', 'TEMP'), ('observation_value', '37')])]), (1495929600000, [OrderedDict([('observation_name', 'PULSE'), ('observation_value', '92')]), OrderedDict([('observation_name', 'O2SAT'), ('observation_value', '97')])])])), ('encounter_reasons', OrderedDict([(1433376000000, [OrderedDict([('reason', 'REFERRAL, PATHOLOGY')]), OrderedDict([('reason', 'NEW PATIENT')]), OrderedDict([('reason', 'SEBACEOUS CYST')])]), (1434412800000, [OrderedDict([('reason', 'DISCUSSION OF RESULTS')])]), (1437177600000, [OrderedDict([('reason', 'URTI, VIRAL')])]), (1442448000000, [OrderedDict([('reason', 'PERTUSSIS PROPHYLAXIS')])]), (1454198400000, [OrderedDict([('reason', 'VIRAL ILLNESS')])]), (1466553600000, [OrderedDict([('reason', 'PHARYNGITIS')])]), (1468281600000, [OrderedDict([('reason', 'CONJUNCTIVITIS')])]), (1468972800000, [OrderedDict([('reason', 'APPOINTUIT ENGAGE SMS: CAMPAIGN #SMS RESULTS NOTIFICATION')])]), (1477180800000, [OrderedDict([('reason', 'REQUEST FOR CLEARANCE')])]), (1491350400000, [OrderedDict([('reason', 'VIRAL ILLNESS')])]), (1493769600000, [OrderedDict([('reason', 'PERTUSSIS PR ...
# ['../.data/medical_data_train_with_metadata/class0/sample_patientid_1638824.pt']
# PatientData(uid=1638824, label=0, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Not stated'), ('gender2', 'Female'), ('smoke', 'Non smoker'), ('irsad', '8'), ('ieo', '9.0'), ('ieo_q', 'Upper quintile'), ('irsad_q', '2nd upper quintile')])])])), ('scripts', OrderedDict([(1426723200000, [OrderedDict([('dose', '1'), ('frequency', 'b.d.'), ('med_active_ingr', 'CEFACLOR'), ('med_name', 'CECLOR CD'), ('quantity', '10'), ('repeats', '1'), ('strength', '375mg')])]), (1538438400000, [OrderedDict([('dose', '1 tab'), ('frequency', 'daily'), ('med_active_ingr', 'CELECOXIB'), ('med_name', 'CELEBREX'), ('quantity', '30'), ('repeats', '0'), ('strength', '200mg')])])])), ('prescriptions', OrderedDict([(1426723200000, [OrderedDict([('first_name_presc', 'CECLOR'), ('first_ingred_presc', 'CEFACLOR'), ('reason', 'URTI')])]), (1538438400000, [OrderedDict([('first_name_presc', 'CELEBREX'), ('first_ingred_presc', 'CELECOXIB'), ('reason', 'CERVICOGENIC HEADACHE')])])])), ('pathology', None), ('immunisations', None), ('observations', OrderedDict([(1446249600000, [OrderedDict([('observation_name', 'LDL'), ('observation_value', '2.1')]), OrderedDict([('observation_name', 'CHOL'), ('observation_value', '4.2')]), OrderedDict([('observation_name', 'BSL'), ('observation_value', '5.7')]), OrderedDict([('observation_name', 'TRIG'), ('observation_value', '0.4')]), OrderedDict([('observation_name', 'HDL'), ('observation_value', '1.9')]), OrderedDict([('observation_name', 'CREATININE'), ('observation_value', '59')])]), (1506038400000, [OrderedDict([('observation_name', 'BSL'), ('observation_value', '4.3')]), OrderedDict([('observation_name', 'CREATININE'), ('observation_value', '64')])]), (1524009600000, [OrderedDict([('observation_name', 'PULSE'), ('observation_value', '62')])]), (1533168000000, [OrderedDict([('observation_name', 'RHYTHM'), ('observation_value', '2')]), OrderedDict([('observation_name', 'PULSE'), ('observation_value', '57')])]), (1533772800000, [OrderedDict([('observation_name', 'PULSE'), ('observation_value', '71')]), OrderedDict([('observation_name', 'RHYTHM'), ('observation_value', '2')])]), (1538438400000, [OrderedDict([('observation_name', 'PULSE'), ('observation_value', '60')]), OrderedDict([('observation_name', 'RHYTHM'), ('observation_value', '2')])])])), ('encounter_reasons', OrderedDict([(1426723200000, [OrderedDict([('reason', 'URTI')])]), (1429228800000, [OrderedDict([('reason', 'REGISTERED NURSE')])]), (1429747200000, [OrderedDict([('reason', 'REGISTERED NURSE')])]), (1434067200000, [OrderedDict([('reason', 'EAR WAX')])]), (1434585600000, [OrderedDict([('reason', 'BILATERAL EAR SYRINGE')])]), (1446163200000, [OrderedDict([('reason', 'PAP (PAPANICOLAOU SMEAR)')]), OrderedDict([('reason', 'MENORRHAGIA')])]), (1447200000000, [OrderedDict([('reason', 'REGISTERED NURSE')])]), (1447372800000, [OrderedDict([('reason', 'FIBROID')])]), (1460678400000, [OrderedDict([('reason', 'MENORRHAGIA')])]), (1463529600000, [OrderedDict([('reason', 'REGISTERED NURSE')])]), (1464307200000, [OrderedDict([('reason', 'IRON DEFICIENCY')])]), (1499817600000, [OrderedDict([('reason', 'DIABETES EDUCATOR')])]), (1502064000000, [OrderedDict([('reason', 'REFERRAL')])]), (1513900800000, [OrderedDict([('reason', 'DIABETES EDUCATOR')])]), (1515024000000, [OrderedDict([('reason', 'DIABETES EDUCATOR')])]), (1521676800000, [OrderedDict([('reason', 'DIABETES EDUCATOR')])]), (1533168000000, [OrderedDict([('reason', 'HEADACHE - CERVICOGENIC')])]), (1533772800000, [OrderedDict([('reason', 'HEADACHE')])]), (1538438400000, [OrderedDict([('reason', 'CERVICOGENIC HEADACHE')])]), (1542844800000, [OrderedDict([('reason', 'HOT FLUSHES')])])]))]))
# ['../.data/medical_data_train_with_metadata/class1/sample_patientid_2783447.pt']
# PatientData(uid=2783447, label=1, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Male'), ('smoke', 'Smoker'), ('irsad', '4'), ('ieo', '3.0'), ('ieo_q', '2nd lower quintile'), ('irsad_q', '2nd lower quintile')])])])), ('scripts', OrderedDict([(1422489600000, [OrderedDict([('dose', '1'), ('frequency', '2'), ('med_active_ingr', 'PANTOPRAZOLE SODIUM SESQUIHYDRATE'), ('med_name', 'SOMAC'), ('quantity', '30'), ('repeats', '5'), ('strength', '40mg')]), OrderedDict([('dose', '1'), ('frequency', '5'), ('med_active_ingr', 'TEMAZEPAM'), ('med_name', 'TEMAZE'), ('quantity', '25'), ('repeats', '0'), ('strength', '10mg')]), OrderedDict([('dose', '1-2'), ('frequency', '5'), ('med_active_ingr', 'PARACETAMOL, CODEINE PHOSPHATE'), ('med_name', 'PANADEINE FORTE 500MG/30MG TABLET'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg;30mg')])]), (1438214400000, [OrderedDict([('dose', '1'), ('frequency', '2'), ('med_active_ingr', 'ESCITALOPRAM OXALATE'), ('med_name', 'LEXAPRO'), ('quantity', '28'), ('repeats', '5'), ('strength', '20mg')]), OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'ATORVASTATIN'), ('med_name', 'ATORVASTATIN'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')]), OrderedDict([('dose', '2'), ('frequency', '8'), ('med_active_ingr', 'PARACETAMOL, CODEINE PHOSPHATE'), ('med_name', 'PANADEINE FORTE 500MG/30MG TABLET'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg;30mg')]), OrderedDict([('dose', '1'), ('frequency', '2'), ('med_active_ingr', 'PANTOPRAZOLE SODIUM SESQUIHYDRATE'), ('med_name', 'SOMAC'), ('quantity', '30'), ('repeats', '5'), ('strength', '40mg')])]), (1441756800000, [OrderedDict([('dose', '1-2'), ('frequency', '8'), ('med_active_ingr', 'PARACETAMOL, CODEINE PHOSPHATE'), ('med_name', 'PANADEINE FORTE 500MG/30MG TABLET'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg;30mg')])]), (1454803200000, [OrderedDict([('dose', '1'), ('frequency', '2'), ('med_active_ingr', 'ESCITALOPRAM OXALATE'), ('med_name', 'LEXAPRO'), ('quantity', '28'), ('repeats', '5'), ('strength', '20mg')]), OrderedDict([('dose', '1'), ('frequency', '2'), ('med_active_ingr', 'PANTOPRAZOLE SODIUM SESQUIHYDRATE'), ('med_name', 'SOMAC'), ('quantity', '30'), ('repeats', '5'), ('strength', '40mg')]), OrderedDict([('dose', '1'), ('frequency', '4'), ('med_active_ingr', 'ATORVASTATIN'), ('med_name', 'ATORVASTATIN'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')])]), (1467849600000, [OrderedDict([('dose', '1'), ('frequency', '5'), ('med_active_ingr', 'MIRTAZAPINE'), ('med_name', 'MIRTAZAPINE'), ('quantity', '30'), ('repeats', '5'), ('strength', '30mg')])]), (1469232000000, [OrderedDict([('dose', '1'), ('frequency', '2'), ('med_active_ingr', 'ESCITALOPRAM OXALATE'), ('med_name', 'LEXAPRO'), ('quantity', '28'), ('repeats', '5'), ('strength', '20mg')]), OrderedDict([('dose', '1'), ('frequency', '4'), ('med_active_ingr', 'ATORVASTATIN'), ('med_name', 'ATORVASTATIN'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')])])])), ('prescriptions', OrderedDict([(1422489600000, [OrderedDict([('first_name_presc', 'PANADEINE'), ('first_ingred_presc', 'PARACETAMOL'), ('reason', '.')]), OrderedDict([('first_name_presc', 'TEMAZE'), ('first_ingred_presc', 'TEMAZEPAM'), ('reason', '.')])]), (1438214400000, [OrderedDict([('first_name_presc', 'PANADEINE'), ('first_ingred_presc', 'PARACETAMOL'), ('reason', '.')])]), (1441756800000, [OrderedDict([('first_name_presc', 'PANADEINE'), ('first_ingred_presc', 'PARACETAMOL'), ('reason', '.')])]), (1467849600000, [OrderedDict([('first_name_presc', 'MIRTAZAPINE'), ('first_ingred_presc', 'MIRTAZAPINE'), ('reason', '.')])]), (1469232000000, [OrderedDict([('first_name_presc', 'LEXAPRO'), ('first_ingred_presc', 'ESCITALOPRAM'), ('reason', '.')])])])), ('pathology', None), ('immunisations', None), ('observations', OrderedDict([(1422489600000, [OrderedDict([('observation_name', 'BMI'),  ...
# ['../.data/medical_data_train_with_metadata/class0/sample_patientid_1998712.pt']
# PatientData(uid=1998712, label=0, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Not stated'), ('gender2', 'Female'), ('smoke', 'Non smoker'), ('irsad', '3'), ('ieo', '4.0'), ('ieo_q', '2nd lower quintile'), ('irsad_q', '2nd lower quintile')])])])), ('scripts', OrderedDict([(1422921600000, [OrderedDict([('dose', '100mg'), ('frequency', '1'), ('med_active_ingr', 'SERTRALINE HYDROCHLORIDE'), ('med_name', 'ZOLOFT'), ('quantity', '30'), ('repeats', '5'), ('strength', '100mg')]), OrderedDict([('dose', '1'), ('frequency', '0'), ('med_active_ingr', 'DIAZEPAM'), ('med_name', 'DIAZEPAM'), ('quantity', '20'), ('repeats', '0'), ('strength', '5mg')]), OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'ESOMEPRAZOLE MAGNESIUM TRIHYDRATE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')])]), (1435363200000, [OrderedDict([('dose', '100mg'), ('frequency', '1'), ('med_active_ingr', 'SERTRALINE HYDROCHLORIDE'), ('med_name', 'ZOLOFT'), ('quantity', '30'), ('repeats', '5'), ('strength', '100mg')]), OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'DROSPIRENONE, ETHINYLOESTRADIOL'), ('med_name', 'YAZ'), ('quantity', '4'), ('repeats', '2'), ('strength', '3mg;20mcg')]), OrderedDict([('dose', ''), ('frequency', '0'), ('med_active_ingr', 'INFLUENZA VACCINE - INACTIVATED, SPLIT VIRION'), ('med_name', 'FLUVAX'), ('quantity', '1'), ('repeats', '0'), ('strength', 'Trivalent')])]), (1435708800000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'PHENTERMINE'), ('med_name', 'DUROMINE'), ('quantity', '30'), ('repeats', '2'), ('strength', '15mg')])]), (1449532800000, [OrderedDict([('dose', '1'), ('frequency', '0'), ('med_active_ingr', 'DIAZEPAM'), ('med_name', 'DIAZEPAM'), ('quantity', '20'), ('repeats', '0'), ('strength', '5mg')]), OrderedDict([('dose', '100mg'), ('frequency', '1'), ('med_active_ingr', 'SERTRALINE HYDROCHLORIDE'), ('med_name', 'ZOLOFT'), ('quantity', '30'), ('repeats', '5'), ('strength', '100mg')]), OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'DROSPIRENONE, ETHINYLOESTRADIOL'), ('med_name', 'YAZ'), ('quantity', '4'), ('repeats', '2'), ('strength', '3mg;20mcg')])]), (1452211200000, [OrderedDict([('dose', '1-2'), ('frequency', '10'), ('med_active_ingr', 'PARACETAMOL, CODEINE PHOSPHATE'), ('med_name', 'PARACETAMOL'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg;30mg')])]), (1452297600000, [OrderedDict([('dose', '2'), ('frequency', '7'), ('med_active_ingr', 'ASPIRIN, CODEINE PHOSPHATE'), ('med_name', 'ASPALGIN'), ('quantity', '20'), ('repeats', '0'), ('strength', '300mg;8mg')])]), (1454025600000, [OrderedDict([('dose', 'Apply'), ('frequency', '7'), ('med_active_ingr', 'CHLORAMPHENICOL'), ('med_name', 'CHLORSIG'), ('quantity', '1'), ('repeats', '0'), ('strength', '1%')])]), (1454716800000, [OrderedDict([('dose', '1'), ('frequency', '6'), ('med_active_ingr', 'AMOXYCILLIN, POTASSIUM CLAVULANATE'), ('med_name', 'AUGMENTIN'), ('quantity', '10'), ('repeats', '1'), ('strength', '875mg;125mg')])]), (1460419200000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'ESOMEPRAZOLE MAGNESIUM TRIHYDRATE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')])]), (1462492800000, [OrderedDict([('dose', '1'), ('frequency', '10'), ('med_active_ingr', 'DICLOXACILLIN'), ('med_name', 'DICLOXACILLIN'), ('quantity', '24'), ('repeats', '0'), ('strength', '500mg')])]), (1464912000000, [OrderedDict([('dose', '100mg'), ('frequency', '1'), ('med_active_ingr', 'SERTRALINE HYDROCHLORIDE'), ('med_name', 'ZOLOFT'), ('quantity', '30'), ('repeats', '5'), ('strength', '100mg')]), OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'DROSPIRENONE, ETHINYLOESTRADIOL'), ('med_name', 'YAZ'), ('quantity', '4'), ('repeats', '2'), ('strength', '3mg;20mcg')])]), (1486339200000, [OrderedDict([('dose', '100mg'), ('frequency', '1'), ('med_active_ingr', 'SERTRALINE HYDROCHLO ...
# ['../.data/medical_data_train_with_metadata/class0/sample_patientid_3016693.pt']
# PatientData(uid=3016693, label=0, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Male'), ('smoke', 'Smoker'), ('irsad', '9'), ('ieo', '9.0'), ('ieo_q', 'Upper quintile'), ('irsad_q', 'Upper quintile')])])])), ('scripts', OrderedDict([(1429574400000, [OrderedDict([('dose', 'bid'), ('frequency', '0'), ('med_active_ingr', 'CHLORAMPHENICOL'), ('med_name', 'CHLORSIG'), ('quantity', '1'), ('repeats', '0'), ('strength', '0.5%')])]), (1431043200000, [OrderedDict([('dose', 'od'), ('frequency', '0'), ('med_active_ingr', 'ROXITHROMYCIN'), ('med_name', 'RULIDE'), ('quantity', '5'), ('repeats', '0'), ('strength', '300mg')]), OrderedDict([('dose', 'prn'), ('frequency', '0'), ('med_active_ingr', 'BENZYDAMINE HYDROCHLORIDE'), ('med_name', 'DIFFLAM'), ('quantity', '1'), ('repeats', '0'), ('strength', '1.5mg/mL')])]), (1431648000000, [OrderedDict([('dose', 'tid'), ('frequency', '0'), ('med_active_ingr', 'CETYLPYRIDINIUM CHLORIDE, DEXTROMETHORPHAN HYDROBROMIDE, BENZOCAINE, MENTHOL'), ('med_name', 'CEPACOL'), ('quantity', '16'), ('repeats', '0'), ('strength', '')]), OrderedDict([('dose', 'od'), ('frequency', '0'), ('med_active_ingr', 'ROXITHROMYCIN'), ('med_name', 'RULIDE'), ('quantity', '5'), ('repeats', '0'), ('strength', '300mg')])]), (1432684800000, [OrderedDict([('dose', '1ml'), ('frequency', '8'), ('med_active_ingr', 'NYSTATIN'), ('med_name', 'NILSTAT'), ('quantity', '1'), ('repeats', '0'), ('strength', '100,000 IU/mL')])]), (1439164800000, [OrderedDict([('dose', 'tid'), ('frequency', '0'), ('med_active_ingr', 'CEPHALEXIN'), ('med_name', 'KEFLEX'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg')])]), (1439769600000, [OrderedDict([('dose', 'tid'), ('frequency', '0'), ('med_active_ingr', 'BENZYDAMINE HYDROCHLORIDE'), ('med_name', 'DIFFLAM'), ('quantity', '1'), ('repeats', '0'), ('strength', '1.5mg/mL')])]), (1443657600000, [OrderedDict([('dose', 'tid'), ('frequency', '0'), ('med_active_ingr', 'AMOXICILLIN'), ('med_name', 'AMOXIL'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg')])]), (1446336000000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'ESOMEPRAZOLE MAGNESIUM TRIHYDRATE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '1'), ('strength', '40mg')])]), (1449273600000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'ESOMEPRAZOLE MAGNESIUM TRIHYDRATE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '1'), ('strength', '40mg')])]), (1489190400000, [OrderedDict([('dose', '1 drop'), ('frequency', '7'), ('med_active_ingr', 'PREDNISOLONE ACETATE, PHENYLEPHRINE HYDROCHLORIDE'), ('med_name', 'PREDNEFRIN'), ('quantity', '1'), ('repeats', '0'), ('strength', '1%-0.12%')])]), (1499904000000, [OrderedDict([('dose', '2tab tid'), ('frequency', '0'), ('med_active_ingr', 'PARACETAMOL, PHENYLEPHRINE, CODEINE, CHLORPHENIRAMINE'), ('med_name', 'CODRAL'), ('quantity', '24'), ('repeats', '0'), ('strength', '500mg;5mg;9.5mg;2mg')]), OrderedDict([('dose', 'tid'), ('frequency', '0'), ('med_active_ingr', 'AMOXICILLIN'), ('med_name', 'AMOXICILLIN'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg')])]), (1504483200000, [OrderedDict([('dose', '2'), ('frequency', '7'), ('med_active_ingr', 'DAY: PARACETAMOL, PHENYLEPHRINE NIGHT: PARACETAMOL, PHENYLEPHRINE, CHLORPHENIRAMINE'), ('med_name', 'CODRAL'), ('quantity', '24'), ('repeats', '0'), ('strength', 'Day: 500mg,5mg,9.5mg Night: 500mg,5mg,2mg')]), OrderedDict([('dose', '2 drops'), ('frequency', '9'), ('med_active_ingr', 'CHLORAMPHENICOL'), ('med_name', 'CHLORSIG'), ('quantity', '1'), ('repeats', '0'), ('strength', '0.5%')])]), (1508716800000, [OrderedDict([('dose', '1 drop'), ('frequency', '7'), ('med_active_ingr', 'ANTAZOLINE, NAPHAZOLINE'), ('med_name', 'ANTAZOLINE/NAPHAZOLINE'), ('quantity', '1'), ('repeats', '0'), ('strength', '0.5%;0.025%')])]), (1513900800000, [OrderedDict([('dose', '2'), ('frequency', '2'), ('med_active_ingr', ' ...
# ['../.data/medical_data_train_with_metadata/class1/sample_patientid_715960.pt']
# PatientData(uid=715960, label=1, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Male'), ('smoke', 'Ex smoker'), ('irsad', '6'), ('ieo', '4.0'), ('ieo_q', '2nd lower quintile'), ('irsad_q', 'intermediate quintile')])])])), ('scripts', OrderedDict([(1524182400000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'METFORMIN HYDROCHLORIDE'), ('med_name', 'METFORMIN'), ('quantity', '100'), ('repeats', '5'), ('strength', '500mg')]), OrderedDict([('dose', '1'), ('frequency', '4'), ('med_active_ingr', 'ATORVASTATIN'), ('med_name', 'ATORVASTATIN'), ('quantity', '30'), ('repeats', '5'), ('strength', '40mg')])]), (1525046400000, [OrderedDict([('dose', ''), ('frequency', '0'), ('med_active_ingr', 'GLUCOSE TEST STRIP, BLOOD'), ('med_name', 'ACCU-CHEK'), ('quantity', '100'), ('repeats', '0'), ('strength', '')]), OrderedDict([('dose', '1'), ('frequency', '6'), ('med_active_ingr', 'METFORMIN HYDROCHLORIDE'), ('med_name', 'METEX'), ('quantity', '120'), ('repeats', '5'), ('strength', '500mg')])])])), ('prescriptions', OrderedDict([(1524182400000, [OrderedDict([('first_name_presc', 'METEX'), ('first_ingred_presc', 'METFORMIN'), ('reason', 'DIABETES MELLITUS, TYPE 2')])]), (1525046400000, [OrderedDict([('first_name_presc', 'ACCU'), ('first_ingred_presc', 'GLUCOSE'), ('reason', 'DIABETES MELLITUS, TYPE 2')])])])), ('pathology', OrderedDict([(1523923200000, [OrderedDict([('result_name', 'POTASSIUM'), ('result_value', '5.3')]), OrderedDict([('result_name', 'AST'), ('result_value', '21')]), OrderedDict([('result_name', 'EGFR'), ('result_value', '81')]), OrderedDict([('result_name', 'MCH'), ('result_value', '27.9')]), OrderedDict([('result_name', 'UREA'), ('result_value', '5.8')]), OrderedDict([('result_name', 'PH'), ('result_value', '6')]), OrderedDict([('result_name', 'U-CREATININE'), ('result_value', '12.5')]), OrderedDict([('result_name', 'NEUTROPHILS'), ('result_value', '4.56')]), OrderedDict([('result_name', 'CEA'), ('result_value', '1.1')]), OrderedDict([('result_name', 'HDL CHOLESTEROL'), ('result_value', '0.9')]), OrderedDict([('result_name', 'TRIGLYCERIDES'), ('result_value', '2.6')]), OrderedDict([('result_name', 'NRBC'), ('result_value', '<1.0')]), OrderedDict([('result_name', 'BASOPHILS'), ('result_value', '0.04')]), OrderedDict([('result_name', 'MCHC'), ('result_value', '311')]), OrderedDict([('result_name', 'URATE'), ('result_value', '0.33')]), OrderedDict([('result_name', 'LDH'), ('result_value', '156')]), OrderedDict([('result_name', 'PHOSPHATE'), ('result_value', '0.95')]), OrderedDict([('result_name', 'BICARBONATE'), ('result_value', '27')]), OrderedDict([('result_name', 'ALBUMIN'), ('result_value', '38')]), OrderedDict([('result_name', 'CALCIUM'), ('result_value', '2.22')]), OrderedDict([('result_name', 'CORRECTED CALCIUM'), ('result_value', '2.32')]), OrderedDict([('result_name', 'ALT'), ('result_value', '23')]), OrderedDict([('result_name', 'CHLORIDE'), ('result_value', '103')]), OrderedDict([('result_name', 'CHOLESTEROL'), ('result_value', '5.2')]), OrderedDict([('result_name', 'TOTAL BILIRUBIN'), ('result_value', '10')]), OrderedDict([('result_name', 'R U-ALBUMIN/CREAT'), ('result_value', '7.5')]), OrderedDict([('result_name', 'R U-ALBUMIN'), ('result_value', '93.9')]), OrderedDict([('result_name', 'EPITHELIAL CELLS'), ('result_value', '0')]), OrderedDict([('result_name', 'CREATININE'), ('result_value', '75')]), OrderedDict([('result_name', 'LEUCOCYTES'), ('result_value', '5')]), OrderedDict([('result_name', 'SODIUM'), ('result_value', '139')]), OrderedDict([('result_name', 'GAMMA GT'), ('result_value', '28')]), OrderedDict([('result_name', 'LDL CHOLESTEROL'), ('result_value', '3.1')]), OrderedDict([('result_name', 'TOTAL PROTEIN'), ('result_value', '67')]), OrderedDict([('result_name', 'TSH'), ('result_value', '1.86')]), OrderedDict([('result_name', 'MONOCYTES'), ('result_value', '0.67')]), OrderedDict([('result_name', ' ...
# ['../.data/medical_data_train_with_metadata/class0/sample_patientid_2445458.pt']
# PatientData(uid=2445458, label=0, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Female'), ('smoke', 'Smoker'), ('irsad', '2'), ('ieo', '1-Most disadvantage'), ('ieo_q', 'Lower quintile'), ('irsad_q', 'Lower quintile')])])])), ('scripts', OrderedDict([(1487721600000, [OrderedDict([('dose', '1'), ('frequency', '2'), ('med_active_ingr', 'SERTRALINE HYDROCHLORIDE'), ('med_name', 'SERTRALINE'), ('quantity', '30'), ('repeats', '2'), ('strength', '100mg')]), OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'LEVONORGESTREL, ETHINYLOESTRADIOL'), ('med_name', 'MICROGYNON'), ('quantity', '4'), ('repeats', '0'), ('strength', '150mcg;30mcg')])]), (1496966400000, [OrderedDict([('dose', '1'), ('frequency', '6'), ('med_active_ingr', 'CEFACLOR'), ('med_name', 'CECLOR'), ('quantity', '10'), ('repeats', '0'), ('strength', '375mg')])]), (1499126400000, [OrderedDict([('dose', '1'), ('frequency', '4'), ('med_active_ingr', 'AMITRIPTYLINE HYDROCHLORIDE'), ('med_name', 'ENDEP'), ('quantity', '50'), ('repeats', '0'), ('strength', '10mg')]), OrderedDict([('dose', '1'), ('frequency', '2'), ('med_active_ingr', 'SERTRALINE HYDROCHLORIDE'), ('med_name', 'SERTRALINE'), ('quantity', '30'), ('repeats', '2'), ('strength', '100mg')])]), (1528848000000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'LEVONORGESTREL, ETHINYLOESTRADIOL'), ('med_name', 'MICRONELLE'), ('quantity', '4'), ('repeats', '2'), ('strength', '150mcg;30mcg')])]), (1529712000000, [OrderedDict([('dose', '1'), ('frequency', '4'), ('med_active_ingr', 'MELATONIN'), ('med_name', 'CIRCADIN'), ('quantity', '30'), ('repeats', '0'), ('strength', '2mg')])])])), ('prescriptions', OrderedDict([(1496966400000, [OrderedDict([('first_name_presc', 'CECLOR'), ('first_ingred_presc', 'CEFACLOR'), ('reason', '')])]), (1499126400000, [OrderedDict([('first_name_presc', 'ENDEP'), ('first_ingred_presc', 'AMITRIPTYLINE'), ('reason', '')])]), (1528848000000, [OrderedDict([('first_name_presc', 'MICRONELLE'), ('first_ingred_presc', 'LEVONORGESTREL'), ('reason', '')])]), (1529712000000, [OrderedDict([('first_name_presc', 'CIRCADIN'), ('first_ingred_presc', 'MELATONIN'), ('reason', 'SLEEPING DIFFICULTY')])])])), ('pathology', None), ('immunisations', None), ('observations', OrderedDict([(1484611200000, [OrderedDict([('observation_name', 'PULSE'), ('observation_value', '80')])]), (1485907200000, [OrderedDict([('observation_name', 'PULSE'), ('observation_value', '67')]), OrderedDict([('observation_name', 'HEIGHT'), ('observation_value', '172.5')]), OrderedDict([('observation_name', 'WEIGHT'), ('observation_value', '49.5')]), OrderedDict([('observation_name', 'BMI'), ('observation_value', '16.6')])]), (1527984000000, [OrderedDict([('observation_name', 'WEIGHT'), ('observation_value', '48.7')])]), (1529712000000, [OrderedDict([('observation_name', 'HEIGHT'), ('observation_value', '172.5')]), OrderedDict([('observation_name', 'BMI'), ('observation_value', '16.0')]), OrderedDict([('observation_name', 'WEIGHT'), ('observation_value', '47.5')]), OrderedDict([('observation_name', 'PULSE'), ('observation_value', '76')])])])), ('encounter_reasons', OrderedDict([(1420070400000, [OrderedDict([('reason', 'ARTHROSCOPY OF KNEE')])]), (1484611200000, [OrderedDict([('reason', 'MALAISE')])]), (1485907200000, [OrderedDict([('reason', 'ANXIETY/DEPRESSION')]), OrderedDict([('reason', 'WORKPLACE BULLYING')]), OrderedDict([('reason', 'LIGHT-HEADEDNESS')]), OrderedDict([('reason', 'NAUSEA')]), OrderedDict([('reason', 'FATIGUE')]), OrderedDict([('reason', 'RESULTS DISCUSSED')]), OrderedDict([('reason', 'ORAL CONTRACEPTIVE')])]), (1486512000000, [OrderedDict([('reason', 'IRON DEFICIENCY')])]), (1487721600000, [OrderedDict([('reason', 'MODERATE IRON DEFICIENCY')]), OrderedDict([('reason', 'RESULTS DISCUSSED')])]), (1496966400000, [OrderedDict([('reason', 'RESPIRATORY TRACT INFECTION')])]), (1499126400000, [OrderedDict([('r ...
# ['../.data/medical_data_train_with_metadata/class1/sample_patientid_2864352.pt']
# PatientData(uid=2864352, label=1, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Not stated'), ('gender2', 'Female'), ('smoke', 'Non smoker'), ('irsad', '6'), ('ieo', '5.0'), ('ieo_q', 'intermediate quintile'), ('irsad_q', 'intermediate quintile')])])])), ('scripts', OrderedDict([(1422403200000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'CONJUGATED EQUINE OESTROGENS, MEDROXYPROGESTERONE'), ('med_name', 'PREMIA'), ('quantity', '28'), ('repeats', '2'), ('strength', '')]), OrderedDict([('dose', '1'), ('frequency', '7'), ('med_active_ingr', 'FAMCICLOVIR'), ('med_name', 'FAMCICLOVIR'), ('quantity', '14'), ('repeats', '0'), ('strength', '250mg')]), OrderedDict([('dose', '1'), ('frequency', '0'), ('med_active_ingr', 'ESOMEPRAZOLE MAGNESIUM TRIHYDRATE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '1'), ('strength', '20mg')])]), (1430784000000, [OrderedDict([('dose', '1'), ('frequency', '6'), ('med_active_ingr', 'HYDROCORTISONE'), ('med_name', 'HYDROCORTISONE'), ('quantity', '1'), ('repeats', '0'), ('strength', '1%')])]), (1434326400000, [OrderedDict([('dose', '1'), ('frequency', '0'), ('med_active_ingr', 'ESOMEPRAZOLE MAGNESIUM TRIHYDRATE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '1'), ('strength', '20mg')]), OrderedDict([('dose', '2 drops'), ('frequency', '7'), ('med_active_ingr', 'TRIAMCINOLONE ACETONIDE, NEOMYCIN SULFATE, GRAMICIDIN, NYSTATIN'), ('med_name', 'KENACOMB'), ('quantity', '1'), ('repeats', '0'), ('strength', '')]), OrderedDict([('dose', '1'), ('frequency', '5'), ('med_active_ingr', 'ROSUVASTATIN'), ('med_name', 'CRESTOR'), ('quantity', '30'), ('repeats', '5'), ('strength', '5mg')])]), (1434931200000, [OrderedDict([('dose', '1'), ('frequency', '0'), ('med_active_ingr', 'ESOMEPRAZOLE MAGNESIUM TRIHYDRATE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')])]), (1440979200000, [OrderedDict([('dose', '1'), ('frequency', '5'), ('med_active_ingr', 'ROSUVASTATIN'), ('med_name', 'CRESTOR'), ('quantity', '30'), ('repeats', '5'), ('strength', '5mg')]), OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'CONJUGATED EQUINE OESTROGENS, MEDROXYPROGESTERONE'), ('med_name', 'PREMIA'), ('quantity', '28'), ('repeats', '2'), ('strength', '')]), OrderedDict([('dose', '1'), ('frequency', '0'), ('med_active_ingr', 'ESOMEPRAZOLE MAGNESIUM TRIHYDRATE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')])]), (1442448000000, [OrderedDict([('dose', '2'), ('frequency', '7'), ('med_active_ingr', 'TRIAMCINOLONE ACETONIDE, NEOMYCIN SULFATE, GRAMICIDIN, NYSTATIN'), ('med_name', 'KENACOMB'), ('quantity', '1'), ('repeats', '0'), ('strength', '')])]), (1442793600000, [OrderedDict([('dose', ''), ('frequency', '0'), ('med_active_ingr', 'PREDNISOLONE'), ('med_name', 'PREDNISOLONE'), ('quantity', '30'), ('repeats', '0'), ('strength', '25mg')])]), (1446422400000, [OrderedDict([('dose', '2'), ('frequency', '0'), ('med_active_ingr', 'TRIAMCINOLONE ACETONIDE, NEOMYCIN SULFATE, GRAMICIDIN, NYSTATIN'), ('med_name', 'KENACOMB'), ('quantity', '1'), ('repeats', '2'), ('strength', '')])]), (1455494400000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'PANTOPRAZOLE SODIUM SESQUIHYDRATE'), ('med_name', 'PANTOPRAZOLE'), ('quantity', '30'), ('repeats', '5'), ('strength', '40mg')])]), (1460678400000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'CONJUGATED EQUINE OESTROGENS, MEDROXYPROGESTERONE'), ('med_name', 'PREMIA'), ('quantity', '28'), ('repeats', '2'), ('strength', '')]), OrderedDict([('dose', '1'), ('frequency', '8'), ('med_active_ingr', 'FLUCLOXACILLIN'), ('med_name', 'FLUCLOXACILLIN'), ('quantity', '24'), ('repeats', '0'), ('strength', '500mg')]), OrderedDict([('dose', '1'), ('frequency', '5'), ('med_active_ingr', 'ROSUVASTATIN'), ('med_name', 'CRESTOR'), ('quantity', '30'), ('repeats', '5'), ('strength', '5mg')]), OrderedDict([('dose', '1'), ('frequency ...
# ['../.data/medical_data_train_with_metadata/class1/sample_patientid_2088872.pt']
# PatientData(uid=2088872, label=1, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Male'), ('smoke', 'Smoker'), ('irsad', '6'), ('ieo', '3.0'), ('ieo_q', '2nd lower quintile'), ('irsad_q', 'intermediate quintile')])])])), ('scripts', OrderedDict([(1420761600000, [OrderedDict([('dose', '1'), ('frequency', '0'), ('med_active_ingr', 'METHYLPREDNISOLONE ACETATE'), ('med_name', 'DEPO-MEDROL'), ('quantity', '1'), ('repeats', '0'), ('strength', '40mg/mL')]), OrderedDict([('dose', 'Topical'), ('frequency', '1'), ('med_active_ingr', 'BETAMETHASONE DIPROPIONATE'), ('med_name', 'ELEUPHRAT'), ('quantity', '1'), ('repeats', '1'), ('strength', '0.05%')]), OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'DIAZEPAM'), ('med_name', 'DIAZEPAM'), ('quantity', '50'), ('repeats', '0'), ('strength', '5mg')]), OrderedDict([('dose', 'Apply'), ('frequency', '6'), ('med_active_ingr', 'FLUOROURACIL'), ('med_name', 'EFUDIX'), ('quantity', '1'), ('repeats', '0'), ('strength', '5%')]), OrderedDict([('dose', '1'), ('frequency', '7'), ('med_active_ingr', 'TRAMADOL HYDROCHLORIDE'), ('med_name', 'ZYDOL'), ('quantity', '20'), ('repeats', '2'), ('strength', '50mg')]), OrderedDict([('dose', 'Apply'), ('frequency', '1'), ('med_active_ingr', 'HYDROCORTISONE ACETATE'), ('med_name', 'CORTIC'), ('quantity', '1'), ('repeats', '1'), ('strength', '1%')])]), (1422489600000, [OrderedDict([('dose', ''), ('frequency', '0'), ('med_active_ingr', 'TRIAMCINOLONE ACETONIDE'), ('med_name', 'TRIAMCINOLONE'), ('quantity', '5'), ('repeats', '0'), ('strength', '10mg/ml')]), OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'DIAZEPAM'), ('med_name', 'DIAZEPAM'), ('quantity', '50'), ('repeats', '0'), ('strength', '5mg')]), OrderedDict([('dose', '1'), ('frequency', '7'), ('med_active_ingr', 'TRAMADOL HYDROCHLORIDE'), ('med_name', 'ZYDOL'), ('quantity', '20'), ('repeats', '2'), ('strength', '50mg')])]), (1423526400000, [OrderedDict([('dose', '1'), ('frequency', '1'), ('med_active_ingr', 'DIAZEPAM'), ('med_name', 'ANTENEX'), ('quantity', '50'), ('repeats', '0'), ('strength', '5mg')]), OrderedDict([('dose', '1'), ('frequency', '7'), ('med_active_ingr', 'TRAMADOL HYDROCHLORIDE'), ('med_name', 'ZYDOL'), ('quantity', '20'), ('repeats', '2'), ('strength', '50mg')])]), (1424995200000, [OrderedDict([('dose', '1'), ('frequency', '0'), ('med_active_ingr', 'DIAZEPAM'), ('med_name', 'VALIUM'), ('quantity', '50'), ('repeats', '0'), ('strength', '5mg')]), OrderedDict([('dose', '2'), ('frequency', '7'), ('med_active_ingr', 'PARACETAMOL, CODEINE PHOSPHATE'), ('med_name', 'PANADEINE'), ('quantity', '180'), ('repeats', '1'), ('strength', '500mg;30mg')]), OrderedDict([('dose', 'Apply'), ('frequency', '1'), ('med_active_ingr', 'HYDROCORTISONE ACETATE'), ('med_name', 'CORTIC'), ('quantity', '1'), ('repeats', '1'), ('strength', '1%')]), OrderedDict([('dose', 'Apply'), ('frequency', '1'), ('med_active_ingr', 'MOMETASONE FUROATE'), ('med_name', 'ELOCON'), ('quantity', '1'), ('repeats', '5'), ('strength', '0.1%')]), OrderedDict([('dose', '1'), ('frequency', '7'), ('med_active_ingr', 'TRAMADOL HYDROCHLORIDE'), ('med_name', 'ZYDOL'), ('quantity', '20'), ('repeats', '2'), ('strength', '50mg')])]), (1426809600000, [OrderedDict([('dose', '1'), ('frequency', '7'), ('med_active_ingr', 'BACLOFEN'), ('med_name', 'BACLOFEN'), ('quantity', '100'), ('repeats', '5'), ('strength', '10mg')]), OrderedDict([('dose', '1'), ('frequency', '0'), ('med_active_ingr', 'DIAZEPAM'), ('med_name', 'VALIUM'), ('quantity', '50'), ('repeats', '0'), ('strength', '5mg')]), OrderedDict([('dose', '1'), ('frequency', '7'), ('med_active_ingr', 'TRAMADOL HYDROCHLORIDE'), ('med_name', 'ZYDOL'), ('quantity', '20'), ('repeats', '2'), ('strength', '50mg')])]), (1428624000000, [OrderedDict([('dose', '2'), ('frequency', '1'), ('med_active_ingr', 'DIAZEPAM'), ('med_name', 'VALIUM'), ('quantity', '50'), ('repeats', '0'), ('strength', '5m ...
# ['../.data/medical_data_train_with_metadata/class1/sample_patientid_516763.pt']
# ...
# ['../.data/medical_data_train_with_metadata/class0/sample_patientid_1270402.pt']
# PatientData(uid=1270402, label=0, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Female'), ('smoke', 'Non smoker'), ('irsad', '5'), ('ieo', '3.0'), ('ieo_q', '2nd lower quintile'), ('irsad_q', 'intermediate quintile')])])])), ('scripts', OrderedDict([(1432857600000, [OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'ETHINYLESTRADIOL/LEVONORGESTREL'), ('med_name', 'TRIFEME'), ('quantity', '4*28'), ('repeats', '2'), ('strength', '50mcg/30mcg (6), 75mcg/40mcg (5), 125mcg/30mcg (10), Inactive (7)')]), OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'ESOMEPRAZOLE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '0'), ('strength', '20mg')])]), (1452211200000, [OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'ESOMEPRAZOLE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '0'), ('strength', '20mg')]), OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'ETHINYLESTRADIOL/LEVONORGESTREL'), ('med_name', 'TRIFEME'), ('quantity', '4*28'), ('repeats', '2'), ('strength', '50mcg/30mcg (6), 75mcg/40mcg (5), 125mcg/30mcg (10), Inactive (7)')]), OrderedDict([('dose', 'apply'), ('frequency', 'b.d.'), ('med_active_ingr', 'SALICYLIC ACID'), ('med_name', 'SALICYLIC ACID IN AQUEOUS CREAM'), ('quantity', '100g'), ('repeats', '0'), ('strength', '5%')])]), (1465516800000, [OrderedDict([('dose', '1-2'), ('frequency', 't.i.d.'), ('med_active_ingr', 'CODEINE/PARACETAMOL'), ('med_name', 'PANADEINE FORTE'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg/30mg')])]), (1468368000000, [OrderedDict([('dose', '2'), ('frequency', 'b.d.'), ('med_active_ingr', 'CEFALEXIN'), ('med_name', 'KEFLEX'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg')])]), (1473379200000, [OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'ETHINYLESTRADIOL/LEVONORGESTREL'), ('med_name', 'TRIFEME'), ('quantity', '4*28'), ('repeats', '2'), ('strength', '50mcg/30mcg (6), 75mcg/40mcg (5), 125mcg/30mcg (10), Inactive (7)')]), OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'ESOMEPRAZOLE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')])]), (1482105600000, [OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'ROXITHROMYCIN'), ('med_name', 'RULIDE'), ('quantity', '5'), ('repeats', '0'), ('strength', '300mg')])]), (1487894400000, [OrderedDict([('dose', '1'), ('frequency', 'stat'), ('med_active_ingr', 'HEPATITIS A VACCINE/TYPHOID (STRAIN TY2) VI POLYSACCHARIDE VACCINE'), ('med_name', 'VIVAXIM'), ('quantity', '1*1.0mL'), ('repeats', '0'), ('strength', '0.025mg/160 ELISA units')]), OrderedDict([('dose', 'apply'), ('frequency', 'daily'), ('med_active_ingr', 'METHYLPREDNISOLONE'), ('med_name', 'ADVANTAN'), ('quantity', '15g'), ('repeats', '0'), ('strength', '0.1%')])]), (1495411200000, [OrderedDict([('dose', '1'), ('frequency', 't.i.d.'), ('med_active_ingr', 'CODEINE/PARACETAMOL'), ('med_name', 'PANADEINE FORTE'), ('quantity', '20'), ('repeats', '0'), ('strength', '500mg/30mg')]), OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'ESOMEPRAZOLE'), ('med_name', 'NEXIUM'), ('quantity', '30'), ('repeats', '5'), ('strength', '20mg')])]), (1501632000000, [OrderedDict([('dose', '1'), ('frequency', 't.i.d.'), ('med_active_ingr', 'FLUOROMETHOLONE'), ('med_name', 'FML LIQUIFILM'), ('quantity', '5mL'), ('repeats', '0'), ('strength', '0.1%')])]), (1521504000000, [OrderedDict([('dose', 'apply'), ('frequency', 't.i.d.'), ('med_active_ingr', 'HYDROCORTISONE'), ('med_name', 'HYDROCORTISONE'), ('quantity', '30g'), ('repeats', '0'), ('strength', '1%')])]), (1533081600000, [OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'ETHINYLESTRADIOL/LEVONORGESTREL'), ('med_name', 'TRIFEME'), ('quantity', '4*28'), ('repeats', '1'), ('strength', '50mcg/30mcg (6), 75mcg/40 ...
# ['../.data/medical_data_train_with_metadata/class0/sample_patientid_2593633.pt']
# PatientData(uid=2593633, label=0, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Male'), ('smoke', 'Non smoker'), ('irsad', '10-Most advantage'), ('ieo', '10-Most advantage'), ('ieo_q', 'Upper quintile'), ('irsad_q', 'Upper quintile')])])])), ('scripts', OrderedDict([(1436918400000, [OrderedDict([('dose', 'apply'), ('frequency', 'b.d.'), ('med_active_ingr', 'MICONAZOLE'), ('med_name', 'DAKTARIN'), ('quantity', '30mL'), ('repeats', '0'), ('strength', '2%')])]), (1445299200000, [OrderedDict([('dose', '1'), ('frequency', 'b.d.'), ('med_active_ingr', 'AMOXICILLIN/CLARITHROMYCIN/ESOMEPRAZOLE'), ('med_name', 'NEXIUM HP7'), ('quantity', '1*14+28+14'), ('repeats', '0'), ('strength', '20mg + 500mg + 500mg')])]), (1454457600000, [OrderedDict([('dose', '1-3 sachet'), ('frequency', ''), ('med_active_ingr', ''), ('med_name', 'MOVICOL LEMON-LIME'), ('quantity', '30'), ('repeats', '5'), ('strength', '13.125g/350.7mg/178.5mg/46.6mg')])]), (1458604800000, [OrderedDict([('dose', 'apply'), ('frequency', 't.i.d.'), ('med_active_ingr', 'MUPIROCIN'), ('med_name', 'BACTROBAN'), ('quantity', '15g'), ('repeats', '0'), ('strength', '2%')])]), (1459814400000, [OrderedDict([('dose', '2 puffs'), ('frequency', 'b.d.'), ('med_active_ingr', 'FLUTICASONE/FORMOTEROL'), ('med_name', 'FLUTIFORM'), ('quantity', '120 dose'), ('repeats', '0'), ('strength', '250mcg-10mcg/actuation')])]), (1466380800000, [OrderedDict([('dose', '1'), ('frequency', 'b.d.'), ('med_active_ingr', 'DOXYCYCLINE'), ('med_name', 'DOXY'), ('quantity', '25'), ('repeats', '0'), ('strength', '50mg')])]), (1468281600000, [OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'TERBINAFINE'), ('med_name', 'LAMISIL'), ('quantity', '42'), ('repeats', '0'), ('strength', '250mg')])]), (1476835200000, [OrderedDict([('dose', 'mdu'), ('frequency', ''), ('med_active_ingr', 'VARICELLA VACCINE'), ('med_name', 'VARICELLA VACCINE (LIVE ATTENUATED OKA STRAIN)'), ('quantity', '2*0.5mL'), ('repeats', '0'), ('strength', '')])]), (1479254400000, [OrderedDict([('dose', '1'), ('frequency', 'daily'), ('med_active_ingr', 'DOXYCYCLINE'), ('med_name', 'DOXY'), ('quantity', '21'), ('repeats', '0'), ('strength', '100mg')])]), (1485734400000, [OrderedDict([('dose', 'mdu'), ('frequency', ''), ('med_active_ingr', 'VARICELLA VACCINE'), ('med_name', 'VARIVAX REFRIGERATED'), ('quantity', '1*0.5mL'), ('repeats', '0'), ('strength', '')])]), (1490659200000, [OrderedDict([('dose', 'apply'), ('frequency', 'b.d.'), ('med_active_ingr', 'HYDROCORTISONE/MICONAZOLE'), ('med_name', 'RESOLVE PLUS 1%'), ('quantity', '30g'), ('repeats', '0'), ('strength', '2%/1%')])]), (1491523200000, [OrderedDict([('dose', 'mdu'), ('frequency', ''), ('med_active_ingr', 'VARICELLA VACCINE'), ('med_name', 'VARIVAX REFRIGERATED'), ('quantity', '1*0.5mL'), ('repeats', '0'), ('strength', '')])]), (1529884800000, [OrderedDict([('dose', '2 sachets'), ('frequency', 'nocte'), ('med_active_ingr', ''), ('med_name', 'MOVICOL FLAVOUR FREE'), ('quantity', '30'), ('repeats', '0'), ('strength', '13.125g/350.8mg/50.2mg/178.6mg')])])])), ('prescriptions', OrderedDict([(1436918400000, [OrderedDict([('first_name_presc', 'DAKTARIN'), ('first_ingred_presc', 'MICONAZOLE'), ('reason', 'ONYCHOMYCOSIS')])]), (1445299200000, [OrderedDict([('first_name_presc', 'NEXIUM'), ('first_ingred_presc', 'AMOXICILLIN'), ('reason', '')])]), (1454457600000, [OrderedDict([('first_name_presc', 'MOVICOL'), ('first_ingred_presc', ''), ('reason', '')])]), (1458604800000, [OrderedDict([('first_name_presc', 'BACTROBAN'), ('first_ingred_presc', 'MUPIROCIN'), ('reason', '')])]), (1459814400000, [OrderedDict([('first_name_presc', 'FLUTIFORM'), ('first_ingred_presc', 'FLUTICASONE'), ('reason', '')])]), (1466380800000, [OrderedDict([('first_name_presc', 'DOXY'), ('first_ingred_presc', 'DOXYCYCLINE'), ('reason', '')])]), (1468281600000, [OrderedDict([('first_name_presc', 'LAMISIL'), ('first_ingred_presc', 'T ...
# ['../.data/medical_data_train_with_metadata/class1/sample_patientid_1995239.pt']
# PatientData(uid=1995239, label=1, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Male'), ('smoke', 'Smoker'), ('irsad', '9'), ('ieo', '9.0'), ('ieo_q', 'Upper quintile'), ('irsad_q', 'Upper quintile')])])])), ('scripts', OrderedDict([(1435536000000, [OrderedDict([('dose', ''), ('frequency', 'stat'), ('med_active_ingr', 'DIPHTHERIA VACCINE/PERTUSSIS VACCINE/TETANUS VACCINE'), ('med_name', 'BOOSTRIX PRESERVATIVE FREE'), ('quantity', '1*0.5mL'), ('repeats', '0'), ('strength', '')])]), (1455321600000, [OrderedDict([('dose', '1'), ('frequency', 'b.d.'), ('med_active_ingr', 'METFORMIN'), ('med_name', 'DIABEX XR'), ('quantity', '60'), ('repeats', '5'), ('strength', '1,000mg')])])])), ('prescriptions', OrderedDict([(1435536000000, [OrderedDict([('first_name_presc', 'BOOSTRIX'), ('first_ingred_presc', 'DIPHTHERIA'), ('reason', '')])]), (1455321600000, [OrderedDict([('first_name_presc', 'DIABEX'), ('first_ingred_presc', 'METFORMIN'), ('reason', 'DIABETES')])])])), ('pathology', None), ('immunisations', OrderedDict([(1440979200000, [OrderedDict([('vaccine_name', 'BOOSTRIX')])])])), ('observations', OrderedDict([(1420243200000, [OrderedDict([('observation_name', 'BSL'), ('observation_value', '8.7')]), OrderedDict([('observation_name', 'CREATININE'), ('observation_value', '50')])]), (1454284800000, [OrderedDict([('observation_name', 'HEIGHT'), ('observation_value', '175')]), OrderedDict([('observation_name', 'BMI'), ('observation_value', '31.7')]), OrderedDict([('observation_name', 'PULSE'), ('observation_value', '99')]), OrderedDict([('observation_name', 'WEIGHT'), ('observation_value', '97')])]), (1454716800000, [OrderedDict([('observation_name', 'CREATININE'), ('observation_value', '55')]), OrderedDict([('observation_name', 'BSL'), ('observation_value', '14.3')]), OrderedDict([('observation_name', 'TRIG'), ('observation_value', '20')]), OrderedDict([('observation_name', 'HBA1C'), ('observation_value', '116')]), OrderedDict([('observation_name', 'MALB'), ('observation_value', '859.0')]), OrderedDict([('observation_name', 'CHOL'), ('observation_value', '12')])])])), ('encounter_reasons', OrderedDict([(1420934400000, [OrderedDict([('reason', 'RESULTS GIVEN/EXPLAINED TO PATIENT')]), OrderedDict([('reason', 'DIABETES')])]), (1440979200000, [OrderedDict([('reason', 'IMMUNISATION - DIPHTHERIA TETANUS PERTUSSIS')]), OrderedDict([('reason', 'IMMUNISATION - PERTUSSIS')])]), (1442966400000, [OrderedDict([('reason', 'GASTROENTERITIS')])]), (1448323200000, [OrderedDict([('reason', 'MECHANICAL LOW BACK PAIN')])]), (1454284800000, [OrderedDict([('reason', 'DIABETES')])]), (1455321600000, [OrderedDict([('reason', 'DIABETES')])])]))]))
# ['../.data/medical_data_train_with_metadata/class1/sample_patientid_1564290.pt']
# PatientData(uid=1564290, label=1, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Not stated'), ('gender2', 'Female'), ('smoke', 'Ex smoker'), ('irsad', '10-Most advantage'), ('ieo', '9.0'), ('ieo_q', 'Upper quintile'), ('irsad_q', 'Upper quintile')])])])), ('scripts', OrderedDict([(1433289600000, [OrderedDict([('dose', 'one'), ('frequency', '6'), ('med_active_ingr', 'AMOXYCILLIN, POTASSIUM CLAVULANATE'), ('med_name', 'AUGMENTIN'), ('quantity', '10'), ('repeats', '1'), ('strength', '875mg;125mg')])]), (1433721600000, [OrderedDict([('dose', 'one'), ('frequency', '7'), ('med_active_ingr', 'TRAMADOL HYDROCHLORIDE'), ('med_name', 'TRAMAL'), ('quantity', '20'), ('repeats', '0'), ('strength', '50mg')])]), (1447113600000, [OrderedDict([('dose', 'one'), ('frequency', '8'), ('med_active_ingr', 'FLUCLOXACILLIN'), ('med_name', 'FLUCLOXACILLIN'), ('quantity', '24'), ('repeats', '0'), ('strength', '500mg')]), OrderedDict([('dose', 'apply'), ('frequency', '6'), ('med_active_ingr', 'MUPIROCIN'), ('med_name', 'BACTROBAN'), ('quantity', '1'), ('repeats', '0'), ('strength', '2%')])])])), ('prescriptions', OrderedDict([(1433289600000, [OrderedDict([('first_name_presc', 'AUGMENTIN'), ('first_ingred_presc', 'AMOXYCILLIN'), ('reason', '')])]), (1433721600000, [OrderedDict([('first_name_presc', 'TRAMAL'), ('first_ingred_presc', 'TRAMADOL'), ('reason', '')])]), (1447113600000, [OrderedDict([('first_name_presc', 'BACTROBAN'), ('first_ingred_presc', 'MUPIROCIN'), ('reason', '')]), OrderedDict([('first_name_presc', 'FLUCLOXACILLIN'), ('first_ingred_presc', 'FLUCLOXACILLIN'), ('reason', '')])])])), ('pathology', None), ('immunisations', None), ('observations', OrderedDict([(1462233600000, [OrderedDict([('observation_name', 'HEIGHT'), ('observation_value', '157CM')]), OrderedDict([('observation_name', 'PULSE'), ('observation_value', '72')]), OrderedDict([('observation_name', 'BMI'), ('observation_value', '26.4')]), OrderedDict([('observation_name', 'WEIGHT'), ('observation_value', '65 KG')])])])), ('encounter_reasons', OrderedDict([(1459468800000, [OrderedDict([('reason', '? TIA')]), OrderedDict([('reason', 'MRI SCAN CRANIUM  FS HOSPITAL')])]), (1462233600000, [OrderedDict([('reason', 'RECENT HOSPITAL ADMISSION ? TIA')])])]))]))
# ['../.data/medical_data_train_with_metadata/class1/sample_patientid_568979.pt']
# PatientData(uid=568979, label=1, data=OrderedDict([('patient', OrderedDict([(0, [OrderedDict([('aborig', 'Neither Aboriginal nor Torres Strait Islander'), ('gender2', 'Male'), ('smoke', 'Non smoker'), ('irsad', '2'), ('ieo', '2.0'), ('ieo_q', 'Lower quintile'), ('irsad_q', 'Lower quintile')])])])), ('scripts', None), ('prescriptions', None), ('pathology', None), ('immunisations', None), ('observations', None), ('encounter_reasons', OrderedDict([(1420070400000, [OrderedDict([('reason', 'COLONIC POLYP(S)')])]), (1438819200000, [OrderedDict([('reason', 'TUBULAR ADENOMA REMOVAL')]), OrderedDict([('reason', 'ANTERIOR RESECTION')])])]))]))
